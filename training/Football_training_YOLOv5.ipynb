# %% [markdown]
# # Football Training with YOLOv5

# %% [markdown]
# ## Dataset: [https://universe.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc/dataset/1](https://universe.roboflow.com/roboflow-jvuqo/football-players-detection-3zvbc/dataset/1)

# %% [markdown]
# ## Connect to drive

# %%
# %cd ..
from google.colab import drive
drive.mount('content/gdrive')
# Out:
# /
# Mounted at content/gdrive

# %%
# !ln -s /content/gdrive/My\ Drive/ /colab

# %%
# !mkdir /colab/FootballwithYOLOv5

# %%
cd /colab/FootballwithYOLOv5
# Out:
# /content/gdrive/My Drive/FootballwithYOLOv5

# %% [markdown]
# ## Set up environment

# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.6/780.6 kB 16.4 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %% [markdown]
# ## Get Dataset from Roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Ienugnsoy8TQnXUFpX9F")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov5pytorch:: 100%|██████████| 1338/1338 [00:12<00:00, 108.45it/s]

# %%
dataset.location
# Out:
# '/content/gdrive/MyDrive/FootballwithYOLOv5/football-players-detection-1'

# %% [markdown]
# ## Move dataset

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/FootballwithYOLOv5

# %%
import shutil

shutil.move('./football-players-detection-1/train/',
            './football-players-detection-1/football-players-detection-1/train/')

shutil.move('./football-players-detection-1/test/',
            './football-players-detection-1/football-players-detection-1/test/')

shutil.move('./football-players-detection-1/valid/',
            './football-players-detection-1/football-players-detection-1/valid/')
# Out:
# './football-players-detection-1/football-players-detection-1/valid/'

# %% [markdown]
# ## Training

# %%
# !yolo task=detect mode=train model=yolov5s.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5s.pt' with new 'model=yolov5su.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100% 17.7M/17.7M [00:00<00:00, 233MB/s]
# Ultralytics YOLOv8.2.31 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
